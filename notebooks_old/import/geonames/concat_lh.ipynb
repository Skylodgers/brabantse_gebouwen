# %%
import os
import glob
import json
import uuid
import pandas as pd
from collections import defaultdict
import pandas as pd
import shutil

save_path = '../../../digipolis-arches-shoku-pkg/packages/lh/pkg/business_data/'

#for f in glob.glob(save_path + '*.csv'):
#    os.remove(f)
    
#for f in glob.glob(save_path + 'relations/' + '*.relations'):
#    os.remove(f)        
    
make_relations = True
    
# Iconografie 17448
# Iconografie_material 17682
i_start_of_records = 0
i_end_of_records   = 100000000000

#
# Object 1480
# Object_material 1480

o_start_of_records = 0
o_end_of_records   = 100000000000

# Tekstdrager 24840
# Tekstdrager_material 24910
t_start_of_records = 0
t_end_of_records   = 100000000000

# %% [markdown]
# # Iconografie

# %%
# %%time

source_path = '../../../digipolis-arches-shoku-pkg/source/lh/Iconografie/'


# e22
i_e22_Acquisitions_df = pd.read_csv(source_path + 'e22_Acquisitions.csv')
i_e22_AcquisitionNumbers_df = pd.read_csv(source_path + 'e22_AcquisitionNumbers.csv')
i_e22_AnnotationsMaterial_df = pd.read_csv(source_path + 'e22_AnnotationsMaterial.csv')
i_e22_Archives_df = pd.read_csv(source_path + 'e22_Archives.csv')
i_e22_Carrier_df = pd.read_csv(source_path + 'e22_Carrier.csv')
i_e22_Conditions_df = pd.read_csv(source_path + 'e22_Conditions.csv')
i_e22_Dimensions_df = pd.read_csv(source_path + 'e22_Dimensions.csv', dtype='str')
i_e22_DimensionSourceNotes_df = pd.read_csv(source_path + 'e22_DimensionSourceNotes.csv')
i_e22_Items_df = pd.read_csv(source_path + 'e22_Items.csv')
i_e22_Marks_df = pd.read_csv(source_path + 'e22_Marks.csv')
i_e22_MaterialColour_df = pd.read_csv(source_path + 'e22_MaterialColour.csv')
i_e22_ProductionActors_df = pd.read_csv(source_path + 'e22_ProductionActors.csv')
i_e22_ProductionTechniqueNote_df = pd.read_csv(source_path + 'e22_ProductionTechniqueNote.csv')
i_e22_ProductionTechniques_df = pd.read_csv(source_path + 'e22_ProductionTechniques.csv')
i_e22_Single_df = pd.read_csv(source_path + 'e22_Single.csv', dtype='str')
i_e22_ObjectTypes_df = pd.read_csv(source_path + 'e22_ObjectTypes.csv')
i_e22_UsageRestrictions_df = pd.read_csv(source_path + 'e22_UsageRestrictions.csv')
i_e22_DamsLinks_df = pd.read_csv(source_path + 'e22_DamsLinks.csv', dtype='str')

Iconografie_material_df = pd.concat([
i_e22_Acquisitions_df,
i_e22_AcquisitionNumbers_df,
i_e22_AnnotationsMaterial_df,
i_e22_Archives_df,
i_e22_Carrier_df,
i_e22_Conditions_df,
i_e22_Dimensions_df,
i_e22_DimensionSourceNotes_df,
i_e22_Items_df,
i_e22_Marks_df,
i_e22_MaterialColour_df,
i_e22_ProductionActors_df,
i_e22_ProductionTechniqueNote_df,
i_e22_ProductionTechniques_df,
i_e22_Single_df,
i_e22_ObjectTypes_df,
i_e22_UsageRestrictions_df,
    i_e22_DamsLinks_df
])

sorted_iconografie_immat_df = Iconografie_material_df.sort_values(by=['ResourceID', 'card', 'order'])
sorted_iconografie_immat_df[i_start_of_records:i_end_of_records].to_csv(save_path + 'Iconografie_material.csv', index=False)
print(len(sorted_iconografie_immat_df))
sorted_iconografie_immat_df = []


# e73
i_e73_AnnotationsImmaterial_df = pd.read_csv(source_path + 'e73_AnnotationsImmaterial.csv')
i_e73_CreationActors_df = pd.read_csv(source_path + 'e73_CreationActors.csv')
i_e73_CreationPlacesSource_lhpr_df = pd.read_csv(source_path + 'e73_CreationPlacesSource_lhpr.csv', dtype='str')
i_e73_CreationPlacesSource_lhtk_df = pd.read_csv(source_path + 'e73_CreationPlacesSource_lhtk.csv', dtype='str')
i_e73_CreationTimeSpans_df = pd.read_csv(source_path + 'e73_CreationTimeSpans.csv', dtype='str')
i_e73_CreationTimeSpanSourceNotes_df = pd.read_csv(source_path + 'e73_CreationTimeSpanSourceNotes.csv', dtype='str')
i_e73_DepictedItems_df = pd.read_csv(source_path + 'e73_DepictedItems.csv')
i_e22_DimensionSourceNotes_df = pd.read_csv(source_path + 'e22_DimensionSourceNotes.csv')
i_e73_Descriptions_df = pd.read_csv(source_path + 'e73_Descriptions.csv')
i_e73_ExternalRelations_df = pd.read_csv(source_path + 'e73_ExternalRelations.csv')
i_e73_LegacyInformation_df = pd.read_csv(source_path + 'e73_LegacyInformation.csv')
i_e73_MaterialRecords_df = pd.read_csv(source_path + 'e73_MaterialRecords.csv')
i_e73_OriginalBrocade_df = pd.read_csv(source_path + 'e73_OriginalBrocade.csv')
i_e73_Titles_df = pd.read_csv(source_path + 'e73_Titles.csv', dtype='str')
i_e73_Single_df = pd.read_csv(source_path + 'e73_Single.csv', dtype='str')
i_e73_LegacyImages_df = pd.read_csv(source_path + 'e73_LegacyImages.csv', dtype='str')
i_e73_Copyrights = pd.read_csv(source_path + 'e73_Copyrights.csv', dtype='str')
i_e73_ChangeHistoryRelations_df = pd.read_csv(source_path + 'e73_ChangeHistoryRelations.csv', dtype='str')

Iconografie_df = pd.concat([
i_e73_AnnotationsImmaterial_df,    
i_e73_CreationActors_df,
i_e73_CreationPlacesSource_lhpr_df,
i_e73_CreationPlacesSource_lhtk_df,
i_e73_CreationTimeSpans_df,
#i_e73_CreationTimeSpanSourceNotes_df,
i_e73_DepictedItems_df,
i_e73_Descriptions_df,
i_e73_ExternalRelations_df,
i_e73_LegacyInformation_df,
i_e73_MaterialRecords_df,
i_e73_OriginalBrocade_df,
i_e73_Titles_df,
i_e73_Single_df,
i_e73_LegacyImages_df,
i_e73_Copyrights,
    i_e73_ChangeHistoryRelations_df

])

sorted_iconografie_df = Iconografie_df.sort_values(by=['ResourceID', 'card', 'order'])
sorted_iconografie_df[i_start_of_records:i_end_of_records].to_csv(save_path + 'Iconografie.csv', index=False)
print(len(sorted_iconografie_df))
sorted_iconografie_df = []

if make_relations:
    t_RelatedResources_df = pd.read_csv(source_path + 'RelatedResources.csv')
    t_RelatedResources_df.to_csv(save_path + 'relations/' + 'Iconografie.relations', index=False)


print('done')
# Out:
# 259717
# 200022
# done
# CPU times: user 7.93 s, sys: 1.77 s, total: 9.7 s
# Wall time: 16.9 s

# %% [markdown]
# ## Object

# %%
# %%time

source_path = '../../../digipolis-arches-shoku-pkg/source/lh/Object/'




# e22
o_e22_Acquisitions_df = pd.read_csv(source_path + 'e22_Acquisitions.csv')
o_e22_AcquisitionNumbers_df = pd.read_csv(source_path + 'e22_AcquisitionNumbers.csv')
o_e22_AnnotationsMaterial_df = pd.read_csv(source_path + 'e22_AnnotationsMaterial.csv')
o_e22_Archives_df = pd.read_csv(source_path + 'e22_Archives.csv')
o_e22_Carrier_df = pd.read_csv(source_path + 'e22_Carrier.csv')
o_e22_Conditions_df = pd.read_csv(source_path + 'e22_Conditions.csv')
o_e22_Dimensions_df = pd.read_csv(source_path + 'e22_Dimensions.csv', dtype='str')
o_e22_DimensionSourceNotes_df = pd.read_csv(source_path + 'e22_DimensionSourceNotes.csv')
o_e22_Items_df = pd.read_csv(source_path + 'e22_Items.csv')
o_e22_Marks_df = pd.read_csv(source_path + 'e22_Marks.csv')
o_e22_Materials_df = pd.read_csv(source_path + 'e22_Materials.csv')
o_e22_MaterialColour = pd.read_csv(source_path + 'e22_MaterialColour.csv')
o_e22_ProductionActors_df = pd.read_csv(source_path + 'e22_ProductionActors.csv')
o_e22_ProductionTechniqueNote_df = pd.read_csv(source_path + 'e22_ProductionTechniqueNote.csv')
o_e22_ProductionTechniques_df = pd.read_csv(source_path + 'e22_ProductionTechniques.csv')
o_e22_Single_df = pd.read_csv(source_path + 'e22_Single.csv', dtype='str')
o_e22_ObjectTypes_df = pd.read_csv(source_path + 'e22_ObjectTypes.csv')
o_e22_UsageRestrictions_df = pd.read_csv(source_path + 'e22_UsageRestrictions.csv')
o_e22_DamsLinks_df = pd.read_csv(source_path + 'e22_DamsLinks.csv', dtype='str')


Object_material_df = pd.concat([
o_e22_Acquisitions_df,
o_e22_AcquisitionNumbers_df,
o_e22_AnnotationsMaterial_df,
o_e22_Archives_df,
o_e22_Carrier_df,
o_e22_Conditions_df,
o_e22_Dimensions_df,
o_e22_DimensionSourceNotes_df,
o_e22_Items_df,
o_e22_Marks_df,
o_e22_Materials_df,
o_e22_MaterialColour,    
o_e22_ProductionActors_df,
o_e22_ProductionTechniqueNote_df,
o_e22_ProductionTechniques_df,
o_e22_Single_df,
o_e22_ObjectTypes_df,
o_e22_UsageRestrictions_df,
    o_e22_DamsLinks_df
    
])

sorted_object_immat_df = Object_material_df.sort_values(by=['ResourceID', 'card', 'order'])
sorted_object_immat_df[o_start_of_records:o_end_of_records].to_csv(save_path + 'Object_material.csv', index=False)
sorted_object_immat_df = []



# e73
o_e73_AnnotationsImmaterial_df = pd.read_csv(source_path + 'e73_AnnotationsImmaterial.csv')
o_e73_CreationActors_df = pd.read_csv(source_path + 'e73_CreationActors.csv')
o_e73_CreationPlacesSource_lhob_df = pd.read_csv(source_path + 'e73_CreationPlacesSource_lhob.csv', dtype='str')
o_e73_CreationPlacesSource_lhsc_df = pd.read_csv(source_path + 'e73_CreationPlacesSource_lhsc.csv', dtype='str')
o_e73_CreationTimeSpans_df = pd.read_csv(source_path + 'e73_CreationTimeSpans.csv', dtype='str')
o_e73_CreationTimeSpanSourceNotes_df = pd.read_csv(source_path + 'e73_CreationTimeSpanSourceNotes.csv', dtype='str')
o_e73_DepictedItems_df = pd.read_csv(source_path + 'e73_DepictedItems.csv')
o_e73_Descriptions_df = pd.read_csv(source_path + 'e73_Descriptions.csv')
o_e73_ExternalRelations_df = pd.read_csv(source_path + 'e73_ExternalRelations.csv')
o_e73_LegacyInformation_df = pd.read_csv(source_path + 'e73_LegacyInformation.csv')
o_e73_MaterialRecords_df = pd.read_csv(source_path + 'e73_MaterialRecords.csv')
o_e73_OriginalBrocade_df = pd.read_csv(source_path + 'e73_OriginalBrocade.csv')
o_e73_Titles_df = pd.read_csv(source_path + 'e73_Titles.csv', dtype='str')
o_e73_Single_df = pd.read_csv(source_path + 'e73_Single.csv', dtype='str')
o_e73_LegacyImages_df = pd.read_csv(source_path + 'e73_LegacyImages.csv', dtype='str')
o_e73_Copyrights = pd.read_csv(source_path + 'e73_Copyrights.csv', dtype='str')
o_e73_ChangeHistoryRelations_df = pd.read_csv(source_path + 'e73_ChangeHistoryRelations.csv', dtype='str')


Object_df = pd.concat([
o_e73_AnnotationsImmaterial_df,    
o_e73_CreationActors_df,
o_e73_CreationPlacesSource_lhob_df,
o_e73_CreationPlacesSource_lhsc_df,
o_e73_CreationTimeSpans_df,
#o_e73_CreationTimeSpanSourceNotes_df,
o_e73_DepictedItems_df,
o_e73_Descriptions_df,
o_e73_ExternalRelations_df,
o_e73_LegacyInformation_df,
o_e73_MaterialRecords_df,
o_e73_OriginalBrocade_df,
o_e73_Titles_df,
o_e73_Single_df,
o_e73_LegacyImages_df,
o_e73_Copyrights,
    o_e73_ChangeHistoryRelations_df
])

sorted_object_df = Object_df.sort_values(by=['ResourceID', 'card', 'order'])
sorted_object_df[o_start_of_records:o_end_of_records].to_csv(save_path + 'Object.csv', index=False)
sorted_object_df = []

if make_relations:
    t_RelatedResources_df = pd.read_csv(source_path + 'RelatedResources.csv')
    t_RelatedResources_df.to_csv(save_path + 'relations/' + 'Object.relations', index=False)


print('done')
# Out:
# done
# CPU times: user 688 ms, sys: 280 ms, total: 968 ms
# Wall time: 2.07 s

# %% [markdown]
# # Tekstdrager

# %%
# %%time

source_path = '../../../digipolis-arches-shoku-pkg/source/lh/Tekstdrager/'


# e22
t_e22_Acquisitions_df = pd.read_csv(source_path + 'e22_Acquisitions.csv')
t_e22_AcquisitionNumbers_df = pd.read_csv(source_path + 'e22_AcquisitionNumbers.csv')
t_e22_AnnotationsMaterial_df = pd.read_csv(source_path + 'e22_AnnotationsMaterial.csv')
t_e22_Archives_df = pd.read_csv(source_path + 'e22_Archives.csv')
t_e22_Conditions_df = pd.read_csv(source_path + 'e22_Conditions.csv')
t_e22_Dimensions_df = pd.read_csv(source_path + 'e22_Dimensions.csv', dtype='str')
t_e22_DimensionSourceNotes_df = pd.read_csv(source_path + 'e22_DimensionSourceNotes.csv')
t_e22_DocumentStatus_df = pd.read_csv(source_path + 'e22_DocumentStatus.csv')
t_e22_Formats_df = pd.read_csv(source_path + 'e22_Formats.csv', dtype='str')
t_e22_Items_df = pd.read_csv(source_path + 'e22_Items.csv')
t_e22_Marks = pd.read_csv(source_path + 'e22_Marks.csv')
t_e22_Materials_df = pd.read_csv(source_path + 'e22_Materials.csv')
t_e22_ProductionActors = pd.read_csv(source_path + 'e22_ProductionActors.csv')
t_e22_ProductStadiums_df = pd.read_csv(source_path + 'e22_ProductStadiums.csv')
t_e22_ProductionTechniques_df = pd.read_csv(source_path + 'e22_ProductionTechniques.csv')
t_e22_Single_df = pd.read_csv(source_path + 'e22_Single.csv', dtype='str')
t_e22_ObjectTypes_df = pd.read_csv(source_path + 'e22_ObjectTypes.csv')
t_e22_UsageRestrictions_df = pd.read_csv(source_path + 'e22_UsageRestrictions.csv')
t_e22_DamsLinks_df = pd.read_csv(source_path + 'e22_DamsLinks.csv', dtype='str')

Tekstdrager_material_df = pd.concat([
t_e22_Acquisitions_df,
t_e22_AcquisitionNumbers_df,
t_e22_AnnotationsMaterial_df,
t_e22_Archives_df,
t_e22_Conditions_df,
t_e22_Dimensions_df,
t_e22_DimensionSourceNotes_df,
t_e22_DocumentStatus_df,
t_e22_Formats_df,
t_e22_Items_df,
t_e22_Marks,
t_e22_Materials_df,
t_e22_ProductionActors,
t_e22_ProductStadiums_df,
t_e22_ProductionTechniques_df,
t_e22_Single_df,
t_e22_ObjectTypes_df,
t_e22_UsageRestrictions_df,    
    t_e22_DamsLinks_df
])

sorted_tekstdrager_material_df = Tekstdrager_material_df.sort_values(by=['ResourceID', 'card', 'order'])
sorted_tekstdrager_material_df[t_start_of_records:t_end_of_records].to_csv(save_path + 'Tekstdrager_material.csv', index=False)
sorted_tekstdrager_material_df = []


# e73
t_e73_AnnotationsImmaterial_df = pd.read_csv(source_path + 'e73_AnnotationsImmaterial.csv')
t_e73_ConnectedSubjects_df = pd.read_csv(source_path + 'e73_ConnectedSubjects.csv')
t_e73_Copyrights = pd.read_csv(source_path + 'e73_Copyrights.csv', dtype='str')
t_e73_CreationPlacesSource_lhhs_df = pd.read_csv(source_path + 'e73_CreationPlacesSource_lhhs.csv')
t_e73_CreationActors_df = pd.read_csv(source_path + 'e73_CreationActors.csv')
t_e73_CreationTimeSpans_df = pd.read_csv(source_path + 'e73_CreationTimeSpans.csv', dtype='str')
t_e73_CreationTimeSpanSourceNotes_df = pd.read_csv(source_path + 'e73_CreationTimeSpanSourceNotes.csv', dtype='str')
t_e73_Descriptions_df = pd.read_csv(source_path + 'e73_Descriptions.csv')
t_e73_ExternalRelations_df = pd.read_csv(source_path + 'e73_ExternalRelations.csv')
t_e73_GenreTypes_df = pd.read_csv(source_path + 'e73_GenreTypes.csv')
t_e73_Languages_df = pd.read_csv(source_path + 'e73_Languages.csv')
t_e73_LegacyInformation_df = pd.read_csv(source_path + 'e73_LegacyInformation.csv')
t_e73_MaterialRecords_df = pd.read_csv(source_path + 'e73_MaterialRecords.csv')
t_e73_OriginalBrocade_df = pd.read_csv(source_path + 'e73_OriginalBrocade.csv')
t_e73_RecordActors_df = pd.read_csv(source_path + 'e73_RecordActors.csv')
t_e73_Titles_df = pd.read_csv(source_path + 'e73_Titles.csv', dtype='str')
t_e73_Single_df = pd.read_csv(source_path + 'e73_Single.csv', dtype='str')
t_e73_LegacyImages_df = pd.read_csv(source_path + 'e73_LegacyImages.csv', dtype='str')
t_e73_ChangeHistoryRelations_df = pd.read_csv(source_path + 'e73_ChangeHistoryRelations.csv', dtype='str')



Tekstdrager_df = pd.concat([
t_e73_AnnotationsImmaterial_df,    
t_e73_ConnectedSubjects_df,
t_e73_Copyrights,
t_e73_CreationPlacesSource_lhhs_df,
t_e73_CreationActors_df,
t_e73_CreationTimeSpans_df,
#t_e73_CreationTimeSpanSourceNotes_df,
t_e73_Descriptions_df,
t_e73_ExternalRelations_df,
t_e73_GenreTypes_df,
t_e73_Languages_df,
t_e73_LegacyInformation_df,
t_e73_MaterialRecords_df,
t_e73_OriginalBrocade_df,
t_e73_RecordActors_df,
t_e73_Titles_df,
t_e73_Single_df,
t_e73_LegacyImages_df,
    t_e73_ChangeHistoryRelations_df
])

sorted_tekstdrager_df = Tekstdrager_df.sort_values(by=['ResourceID', 'card', 'order'])
sorted_tekstdrager_df[t_start_of_records:t_end_of_records].to_csv(save_path + 'Tekstdrager.csv', index=False)
sorted_tekstdrager_df = []

if make_relations:
    t_RelatedResources_df = pd.read_csv(source_path + 'RelatedResources.csv')
    t_RelatedResources_df.to_csv(save_path + 'relations/' + 'Tekstdrager.relations', index=False)


print('done')
# Out:
# done
# CPU times: user 7.37 s, sys: 340 ms, total: 7.71 s
# Wall time: 8.02 s

# %% [markdown]
# ## Change History

# %%
transactions_dir = '../../source/static/tg_history/'
_dataset = 'lh'

read_name = transactions_dir  + _dataset + '_Change History Log.csv'
save_name = '../../../digipolis-arches-shoku-pkg/packages/lh/pkg_600_lh/business_data/Change History Log.csv'

try:
    shutil.copy2(read_name, save_name) 
    print('ChangeHistory copied to business_data') 
except:
    print('Naah, not copied')
# Out:
# ChangeHistory copied to business_data

# %%
# %reset -f
