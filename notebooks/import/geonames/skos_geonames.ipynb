# %%
import os
import json
import pandas as pd
import csv
from lxml import etree
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, SKOS, DCTERMS, DC, OWL
import uuid

ark_id = "1552"

# %%
## Language code

# %%
def generate_skos(_list, _voc):
    
    NS = Namespace("")
    g = Graph()
    g.bind("ns", NS)
    g.bind("skos", SKOS)
    g.bind("dcterms", DCTERMS)
    g.bind("dc", DC)

    voc_name = _voc
    voc_uri = NS[f'https://n2t.net/ark:/{ark_id}/{voc_name}/{str(uuid.uuid5(uuid.NAMESPACE_DNS, _voc))}']
    
    g.add((voc_uri, RDF.type, SKOS['ConceptScheme']))
    g.add((voc_uri, DCTERMS.title, Literal(voc_name,lang="nl")))
    g.add((voc_uri, DCTERMS.title, Literal(voc_name,lang="en")))

    for row in _list:
        
        uri = NS[row['uri']]
        g.add((uri, SKOS.inScheme, voc_uri))
        g.add((voc_uri, SKOS.hasTopConcept, uri))        
        g.add((uri, RDF.type, SKOS.Concept))
        g.add((uri, SKOS.prefLabel, Literal(row['prefLabel'], lang="nl")))
        g.add((uri, SKOS.inScheme, voc_uri))
        g.add((uri, SKOS.altLabel, Literal(row['altLabel'], lang="nl")))

    skos_data = g.serialize(format='pretty-xml').decode('utf-8')
    with open(f'./skos/{voc_name}.xml', "w") as f:
        f.write(skos_data)
    
    
    #skos_data = ''
    del g
    return skos_data

source_file = './source/iso-languagecodes.txt'
with open(source_file, newline='') as csvfile:
    concepts = csv.reader(csvfile, delimiter='\t')
    next(concepts, None)

    concept_dict = {}
    concept_list = []

    for row in concepts:
        if len(row[2]) > 0:
            
            concept_dict = {
                "uri": f'https://n2t.net/ark:/{ark_id}/{str(uuid.uuid5(uuid.NAMESPACE_DNS, row[2]))}',
                "prefLabel": row[2],
                "altLabel": row[3]
            }
            concept_list.append(concept_dict)
    
    #print(json.dumps(concept_list, indent=2))
    voc_name = 'Language ISO Type'
    skos_data = generate_skos(concept_list, voc_name)
    with open(f'./skos/{voc_name}.xml', "w") as f:
        f.write(skos_data)
    #print(skos)

# %% [markdown]
# ## Feature Codes
#
# https://www.geonames.org/ontology#WikipediaArticle
# https://www.geonames.org/ontology#Map
# https://www.geonames.org/ontology#GeonamesFeature
# https://www.geonames.org/ontology#Code
# https://www.geonames.org/ontology#RDFData
# https://www.geonames.org/ontology#Feature
# https://www.geonames.org/ontology#Class

# %%
from rdflib import Graph, Namespace, RDF
from rdflib.namespace import SKOS

# Define GeoNames namespace
GEO = Namespace("https://www.geonames.org/ontology#")
g.bind("gn", GEO)
                
# Load the GeoNames OWL data
g = Graph()
g.parse('./source/geonames_onto.rdf')

# Create a new graph for SKOS (if you need to create a separate graph for modification)
skos_graph = Graph()

# Iterate over instances of gn:Code
print("Extracting SKOS data from GeoNames codes...")

for code in g.subjects(RDF.type, GEO.Code):
    print(f"Processing code: {code}")
    
    # Extract SKOS properties
    for p, o in g.predicate_objects(code):
        if p.startswith(SKOS):  # Only include SKOS properties
            skos_graph.add((code, p, o))
            print(f"  Added SKOS triple: {p} -> {o}")

# Save the extracted SKOS graph to a new RDF/XML file
skos_graph.serialize('geonames_extracted_skos.rdf', format='pretty-xml')
print("SKOS extraction complete. File saved as 'geonames_extracted_skos.rdf'.")
# Out:
# Extracting SKOS data from GeoNames codes...
# Processing code: https://www.geonames.org/ontology#P.PPLF
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#P
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> farm village
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a populated place where the population is largely engaged in agricultural activities
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> P.PPLF
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> деревня
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> населенный пункт, где большая часть населения занята в сельским хозяйством
# Processing code: https://www.geonames.org/ontology#S.ESTSG
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> захарна плантация
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> an estate that specializes in growing sugar cane
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> sukkerplantasje
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> sockerplantage
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> большая земельная площадь, на которой выращивают сахарный тростник
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#S
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> сахарная плантация
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> sugar plantation
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> S.ESTSG
# Processing code: https://www.geonames.org/ontology#U.BDLU
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> бордерленд
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> gränsland
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> невысокий порог, отделяющий геосинклиналь от океана
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> Гранична област
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> U.BDLU
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a region adjacent to a continent, normally occupied by or bordering a shelf, that is highly irregular with depths well in excess of those typical of a shelf
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> grenseområde
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> borderland
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#U
# Processing code: https://www.geonames.org/ontology#L.CMN
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> allmänt område
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> L.CMN
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#L
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> общинные земли
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> обществена собственост
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> allmenning
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> земли (выгоны, сенокосы, леса), которые  находятся в общем пользовании
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> common
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a park or pasture for community use
# Processing code: https://www.geonames.org/ontology#S.NOV
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a religious house or school where novices are trained
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> дом послушничества
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> семинария
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> novitiate
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> S.NOV
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> религиозный дом, где учатся послушники, готовящиеся стать монахами
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> novitiat
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> novisiat
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#S
# Processing code: https://www.geonames.org/ontology#H.CNFL
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> sammanflöde
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#H
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a place where two or more streams or intermittent streams flow together
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> устие
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> sammenløp
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> место слияние (рек)
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> confluence
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> место, где две (или больше) реки соединяются в одну
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> H.CNFL
# Processing code: https://www.geonames.org/ontology#S.DCKD
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#S
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> портовое сооружение для ремонта и постройки судов; сухой док сооружается на защищённой от волнения акватории и представляет собой отделяемую от неё с торца затвором водонепроницаемую камеру
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> dry dock
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> torrdocka
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> сухой док
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> S.DCKD
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> demning gravd ned til grunnfjellet
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a dock providing support for a vessel, and means for removing the water so that the bottom of the vessel can be exposed
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> сух док
# Processing code: https://www.geonames.org/ontology#U.PLTU
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> plateau
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> platå
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> U.PLTU
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#U
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> возвышенная равнина, ограниченная чётко выраженными уступами, крутыми склонами
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> platå
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> плато
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> плато
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a comparatively flat-topped feature of considerable extent, dropping off abruptly on one or more sides
# Processing code: https://www.geonames.org/ontology#U.ARRU
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> arrugado
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> U.ARRU
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#U
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> arrugado
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> an area of subdued corrugations off Baja California
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> arrugado
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> an area of subdued corrugations off Baja California
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> veckig
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> Нагъване
# Processing code: https://www.geonames.org/ontology#S.HSPD
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> apotek
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> dispensary
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> S.HSPD
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> медицинское учреждение, занимающееся лечением и предупреждением болезней путём систематического врачебного наблюдения
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a building where medical or dental aid is dispensed
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#S
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> klinik
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> диспансер
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> диспансер
# Processing code: https://www.geonames.org/ontology#T.RKS
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> остроконечные горные вершины или высшие точки горной вершины вообще
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> klipper
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> conspicuous, isolated rocky masses
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> скалы
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> T.RKS
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> klippor
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#T
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> rocks
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> скали
# Processing code: https://www.geonames.org/ontology#S.TRIG
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> trianguleringsstation
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> триангуляционный пост
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#S
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> триангулачна точка
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> S.TRIG
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> опорный геодезический пункт, созданный методом триангуляции (геодезия)
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a point on the earth whose position has been determined by triangulation
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> triangulation station
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> trianguleringsstasjon
# Processing code: https://www.geonames.org/ontology#V.VINS
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> plantings of grapevines
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> виноградники
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> виноградные плантации
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> vingårdar
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> vingårder
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#V
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> V.VINS
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> vineyards
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> лозя
# Processing code: https://www.geonames.org/ontology#S.OILW
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> oljekälla
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> петролен кладенец
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> oil well
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> S.OILW
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> вертикальная горная выработка круглого сечения, предназначенная для разведки либо добычи нефти и попутного газа
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#S
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> нефтяная скважина
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> oljebrønn
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a well from which oil may be pumped
# Processing code: https://www.geonames.org/ontology#S.PRKGT
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> S.PRKGT
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> ворота парка
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> park gate
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a controlled access to a park
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> parkingång
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> паркова бариера
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> вход в парк, запираемый створами
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> inngang til militæranlegg
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#S
# Processing code: https://www.geonames.org/ontology#T.MRN
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> морена
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a mound, ridge, or other accumulation of glacial till
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> скопление обломков горных пород, образуемое на границе передвижения и таяния ледников
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#T
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> moraine
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> морена
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> morän
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> T.MRN
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> morene
# Processing code: https://www.geonames.org/ontology#L.RESN
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> особо охраняемая природная  территория
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#L
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> naturreservat
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> природен резерват
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> an area reserved for the maintenance of a natural habitat
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> nature reserve
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> naturreservat
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> особо охраняемые участки земли, водной поверхности и воздушного пространства над ними, где располагаются природные комплексы и объекты, которые имеют свое научное, культурное, эстетическое и оздоровительное значение, которые изъяты решениями органов государственной власти полностью или частично из хозяйственного использования
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> L.RESN
# Processing code: https://www.geonames.org/ontology#H.LGNX
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> H.LGNX
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> del av lagun
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> част от кагуна
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> участок лагуны
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> section of lagoon
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> del av lagune
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#H
# Processing code: https://www.geonames.org/ontology#T.CLDA
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> caldera
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> кальдера
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a depression measuring kilometers across formed by the collapse of a volcanic mountain
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> T.CLDA
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> Вулканично пропадане
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> котлообразная впадина с крутыми склонами и ровным дном, образовавшаяся вследствие провала вершины вулкана, а иногда и прилегающей к нему местности
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#T
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> caldera
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> krater
# Processing code: https://www.geonames.org/ontology#U.HOLU
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#U
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> hål
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> впадина
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> U.HOLU
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> hole
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> Вдлъбнатина
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> понижение земной поверхности в пределах суши, на дне океанов и морей
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> hull
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a small depression of the sea floor
# Processing code: https://www.geonames.org/ontology#H.LKSI
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> intermittent lakes
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> tilbakevendende innsjøer
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> исчезающие озера
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#H
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> пресъхващи езера
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> periodiska sjöar
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> H.LKSI
# Processing code: https://www.geonames.org/ontology#S.MNNI
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> S.MNNI
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#S
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> nickel mine(s)
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a mine where nickel ore is extracted
# Processing code: https://www.geonames.org/ontology#V.FRSTF
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> forsteinet skog
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a forest fossilized by geologic processes and now exposed at the earth's surface
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> горски вкаменелости
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> fossilized forest
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> значительное скопление древесных окаменелостей на небольшом участке
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> V.FRSTF
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#V
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> окаменелый лес
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> fossil skog
# Processing code: https://www.geonames.org/ontology#H.WADJ
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> wadi-sammenløp
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> възел на вади
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#H
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> wadi junction
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a place where two or more wadies join
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> место слияния двух или более вади
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> flodförbindning
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> H.WADJ
# Processing code: https://www.geonames.org/ontology#R.TNLRR
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a tunnel through which a railroad passes
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#R
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> järnvägstunnel
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> железнодорожный туннель
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> R.TNLRR
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> жп тунел
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> railroad tunnel
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> jernbanetunnel
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> тоннель, по которому проходит ж/д дорога
# Processing code: https://www.geonames.org/ontology#S.AIRH
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> heliport
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#S
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> landningsplats för helikopter
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a place where helicopters land and take off
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> земельный участок, площадка на здании, судне и т.п., оборудованные для взлёта, посадки и обслуживания вертолётов
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> летище за хеикоптери
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> вертолетная площадка
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> S.AIRH
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> heliport
# Processing code: https://www.geonames.org/ontology#S.HSEC
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> загородный дом
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> дом, находящийся за городом, вне города, вблизи от него
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> S.HSEC
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> country house
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#S
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> landsted
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a large house, mansion, or chateau, on a large estate
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> селска къща
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> lantgods
# Processing code: https://www.geonames.org/ontology#S.STNE
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> eksperimentstasjon
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> S.STNE
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> место проведения различного рода испытаний
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> experimentstation
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> експериментална станция
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a facility for carrying out experiments
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> experiment station
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#S
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> испытательная станция
# Processing code: https://www.geonames.org/ontology#A.ADM4
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#A
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> A.ADM4
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> политико-административное деление четвертого порядка
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> administrativ inndeling av fjerde grad
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> четвъртостепенна административна единица
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> дальнейшее деление политико-административного деления третьего порядка
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> fjärde ordningens administrativ avdelning
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a subdivision of a third-order administrative division
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> fourth-order administrative division
# Processing code: https://www.geonames.org/ontology#H.CHNL
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> наиболее глубокое место в озере; здесь могут проходить суда
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> seilingskanal i innsjø
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> омут
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> sjökanal(er)
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> lake channel(s)
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> that part of a lake having water deep enough for navigation between islands, shoals, etc.
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> езерен канал(и)
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> H.CHNL
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#H
# Processing code: https://www.geonames.org/ontology#L.RESV
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#L
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> резервация
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> reservat
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> территории, отведенные для поселения коренного населения страны
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> reservation
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a tract of land set aside for aboriginal, tribal, or native populations
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> reservat
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> L.RESV
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> резерват
# Processing code: https://www.geonames.org/ontology#L.MNA
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> gruveområde
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> L.MNA
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> район добычи полезных ископаемых
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> an area of mine sites where minerals and ores are extracted
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#L
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> gruvområde
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> район разработки
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> полезни ископаеми
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> mining area
# Processing code: https://www.geonames.org/ontology#H.STMC
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> H.STMC
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#H
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> kanalisert bekk
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> водоток канала
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a stream that has been substantially ditched, diked, or straightened
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> kanaliserat vattendrag
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> канализиран поток
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> естественный или искусственный водный поток канала
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> canalized stream
# Processing code: https://www.geonames.org/ontology#S.BDG
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> S.BDG
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> сооружение для перехода, переезда через реку, овраг, железнодорожный путь и т.п.
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> bro
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> bro
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> мост
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> bridge
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a structure erected across an obstacle such as a stream, road, etc., in order to carry roads, railroads, and pedestrians across
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#S
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> мост
# Processing code: https://www.geonames.org/ontology#T.PASS
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> ущелье, узкий, тесный проход между возвышенностями или водными преградами (в котором можно остановить противника)
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> bergspass, trång väg(passage)
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> Дефиле
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> дефиле
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#T
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a break in a mountain range or other high obstruction, used for transportation from one side to the other [See also gap]
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> pass
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> T.PASS
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> pass
# Processing code: https://www.geonames.org/ontology#S.NSY
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a place where plants are propagated for transplanting or grafting
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> тёплое с покрытием из прозрачного материала помещение для выращивания ранних овощей, цветов, теплолюбивых растений; оранжерея
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> barnehage
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> парник(-ци)
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> S.NSY
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> nursery(-ies)
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#S
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> plantskola
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> теплица
# Processing code: https://www.geonames.org/ontology#S.HERM
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> eremitage
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> жилище монахов-отшельников
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a secluded residence, usually for religious sects
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#S
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> скит
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> eneboerhytte
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> отшелническа килия
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> S.HERM
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> hermitage
# Processing code: https://www.geonames.org/ontology#L.OILF
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> oilfield
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> oljefelt
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> L.OILF
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#L
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> петролно находище
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> an area containing a subterranean store of petroleum of economic value
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> oljefält
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> нефтяное месторождение
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> место под землей, где залегают запасы нефти
# Processing code: https://www.geonames.org/ontology#U.ARCU
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#U
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> arch
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> дуга
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> bue
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a low bulge around the southeastern end of the island of Hawaii
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> Арка
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> U.ARCU
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> båge, valv
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> территория, пространство, границы которого имеют форму изогнутой линии (например, дуга на юго-востоке Гавайского хребта)
# Processing code: https://www.geonames.org/ontology#S.TWO
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> Temporary Work Offices
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> биржа труда
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#S
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> учреждение, осуществляющее посредничество между предпринимателями и наёмными работниками
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> temp work office
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> temp work office
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> Temp Work Office
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> temp work office
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> S.TWO
# Processing code: https://www.geonames.org/ontology#T.VALG
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> Наклонена долина
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> hängdal
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a valley the floor of which is notably higher than the valley or shore to which it leads; most common in areas that have been glaciated
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> висячая долина
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> hengende dal
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#T
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> hanging valley
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> T.VALG
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> боковая долина, днище которой оканчивается выше днища главной долины
# Processing code: https://www.geonames.org/ontology#S.FNDY
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> мастерская, в которой происходит обработка металла путем плавления и заливки в литейные формы
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a building or works where metal casting is carried out
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> gjuteri
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> литейный цех
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> foundry
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> støperi
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> S.FNDY
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#S
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> леярна
# Processing code: https://www.geonames.org/ontology#V.GRVC
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> большой участок земли, занятый кокосовыми деревьями
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> coconut grove
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> kokospalmelund
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a planting of coconut trees
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> кокосови насаждения
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> kokoslund
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> V.GRVC
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#V
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> плантация кокосовых деревьев
# Processing code: https://www.geonames.org/ontology#T.SPUR
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> ответвление основной горной цепи
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> spur(s)
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a subordinate ridge projecting outward from a hill, mountain or other elevation
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#T
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> T.SPUR
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> utlöpare
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> отрог
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> utspring
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> Издадена скала(и)
# Processing code: https://www.geonames.org/ontology#L.REP
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> republic
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> L.REP
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#L
# Processing code: https://www.geonames.org/ontology#S.MFGCU
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> предприятие по переработке медной руды
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> kopparbruk
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#S
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> медна фабрика
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> S.MFGCU
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> медеплавильный завод
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> copper works
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a facility for processing copper ore
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> kopperverk
# Processing code: https://www.geonames.org/ontology#T.REG
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a desert plain characterized by a surface veneer of gravel and stones
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> каменистая пустыня
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> гаммада
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> steinørken
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> T.REG
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> stony desert
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> stenöken
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> камениста пустиня
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#T
# Processing code: https://www.geonames.org/ontology#H.STMX
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#H
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> участок ручья
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> section of stream
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> del av bekk
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> част от поток
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> del av vattendrag
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> H.STMX
# Processing code: https://www.geonames.org/ontology#H.GYSR
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> geyser
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> гейзер
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> geysir
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#H
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> H.GYSR
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a type of hot spring with intermittent eruptions of jets of hot water and steam
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> geyser
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> источник вулканического происхождения, выбрасывающий через определённые промежутки времени фонтаны горячей воды и пара
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> гейзер
# Processing code: https://www.geonames.org/ontology#H.STMIX
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> участок реки с периодическим водотоком
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> част от пресъхващ пото
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> del av periodiskt vattendrag
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> section of intermittent stream
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> del av tilbakevendende bekk
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#H
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> H.STMIX
# Processing code: https://www.geonames.org/ontology#H.STM
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> H.STM
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> å, bäck, ström
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> ручей
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a body of running water moving to a lower level in a channel on land
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> stream
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> небольшой мелкий водоток с постоянным или временным течением
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#H
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> bekk
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> поток
# Processing code: https://www.geonames.org/ontology#T.HLL
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> ås
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#T
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a rounded elevation of limited extent rising above the surrounding land with local relief of less than 300m
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> kulle
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> холм
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> възвишение
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> T.HLL
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> небольшая отлогая горка, возвышенность округлой или овальной формы с пологими склонами
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> hill
# Processing code: https://www.geonames.org/ontology#H.PNDSN
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> соленые пруды
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> солени езерца
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> H.PNDSN
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> saltvannsdammer
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#H
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> salt ponds
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> saltdammar
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> небольшие водоемы с соленой водой, обычно в болотистой местности, или вдоль морского побережья
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> small standing bodies of salt water often in a marsh or swamp, usually along a seacoast
# Processing code: https://www.geonames.org/ontology#H.DOMG
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> H.DOMG
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> ледниковый купол
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> ледено покритие
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> välvd iskalott
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a comparatively elevated area on an icecap
# ...
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> cutoff
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> H.CUTF
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> обводной канал
# Processing code: https://www.geonames.org/ontology#S.LTHSE
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#S
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a distinctive structure exhibiting a major navigation light
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> фар
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> S.LTHSE
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> fyr
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> сооружение башенного типа, служащее ориентиром для опознавания берегов, определения места судна и предупреждения о навигационной опасности
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> световой маяк
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> fyrtårn
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> lighthouse
# Processing code: https://www.geonames.org/ontology#S.FRMQ
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> S.FRMQ
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> forlatt gård
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#S
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> покинутая (заброшенная) ферма
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> abandoned farm
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> изоставена ферма
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> övergiven farm
# Processing code: https://www.geonames.org/ontology#T.PLATX
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> T.PLATX
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> del av platå
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#T
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> del av platå
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> част от плато
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> section of plateau
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> участок плато
# Processing code: https://www.geonames.org/ontology#S.SWT
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> очистное сооружение
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> sewage treatment plant
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> facility for the processing of sewage and/or wastewater
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> S.SWT
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> комплекс инженерных сооружений в системе канализации населённого места или промышленного предприятия, предназначенный для очистки
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#S
# Processing code: https://www.geonames.org/ontology#H.TNLC
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> H.TNLC
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> kanaltunnel
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> canal tunnel
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#H
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> canal tunnel
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a tunnel through which a canal passes
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> судоходный тоннель
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> тоннель, сооружаемый при пересечении судоходным каналом возвышенности, горного хребта и т. п.
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> канален тунел
# Processing code: https://www.geonames.org/ontology#T.LAVA
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> район застывшей лавы
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> lava area
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> зона с лава
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> an area of solidified lava
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> lavaområde
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#T
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> lavaområde
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> T.LAVA
# Processing code: https://www.geonames.org/ontology#A.PCLS
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> полу-независимо политическо образувание
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> A.PCLS
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> delvis uavhengig politisk enhet
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> наполовину зависимое политическое образование
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> delvis oberoende politisk enhet
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#A
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> semi-independent political entity
# Processing code: https://www.geonames.org/ontology#H.COVE
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> заливче
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a small coastal indentation, smaller than a bay
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> cove(s)
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> kil
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> H.COVE
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> прибойная пещера
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> liten vik
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#H
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> защищённое, закрытое место в скалах на морском берегу
# Processing code: https://www.geonames.org/ontology#S.OPRA
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> театр; оперная труппа театра
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> A theater designed chiefly for the performance of operas.
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> operahus
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> opera house
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#S
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> опера
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> S.OPRA
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> operahus
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> оперный дом
# Processing code: https://www.geonames.org/ontology#S.ML
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> kvarn
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> промышленное предприятие, обрабатывающее сырье машинным способом
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> mølle
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> S.ML
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> мелница(и)
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#S
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> mill(s)
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> фабрика
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a building housing machines for transforming, shaping, finishing, grinding, or extracting products
# Processing code: https://www.geonames.org/ontology#H.WAD
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> H.WAD
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> вади
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> wadi
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> сухи речни корита (вади)
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> wadi
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> русло или долина пересыхающего водотока; в Азии, в Африке
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> flod
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a valley or ravine, bounded by relatively steep banks, which in the rainy season becomes a watercourse; found primarily in North Africa and the Middle East
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#H
# Processing code: https://www.geonames.org/ontology#H.BGHT
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> an open body of water forming a slight recession in a coastline
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#H
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> vik
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> bukt(er)
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> bight(s)
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> ивица(и)
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> открытый участок воды; там, где происходит отступание береговой черты
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> излучина (реки)
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> H.BGHT
# Processing code: https://www.geonames.org/ontology#S.MLWTR
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> гидротехнические сооружение, использующее гидроэнергию, получаемую с водяного колеса, движение которого выполняет полезную работу посредством зубчатой передачи
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> водяная мельница
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> водна мелница
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> kvernhus
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a mill powered by running water
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> vattenkvarn
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> water mill
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#S
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> S.MLWTR
# Processing code: https://www.geonames.org/ontology#S.MNPB
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> lead mine(s)
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a mine where lead ore is extracted
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> S.MNPB
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#S
# Processing code: https://www.geonames.org/ontology#U.SMU
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> undervattensberg
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> undersjøisk fjell
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> Морски върхове
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> подводная гора
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> an elevation rising generally more than 1,000 meters and of limited extent across the summit
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#U
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> изолированное поднятие морского дна с относительной высотой более 500 м и четко выраженной конической или куполообразной одной или несколькими вершинами и крутыми склонами
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> U.SMU
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> seamount
# Processing code: https://www.geonames.org/ontology#H.LKOI
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#H
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> временно исчезающее пойменное озеро
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> intermittent oxbow lake
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> tilbakevendende kroksjø
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> пресъхващи корекции
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> H.LKOI
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> peridodisk uformad sjö
# Processing code: https://www.geonames.org/ontology#H.RCH
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#H
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> reach
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> H.RCH
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> част на река между два завоя/на канал между два шлюза
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a straight section of a navigable stream or channel between two bends
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> участок реки между изгибами, перекатами с широким, спокойным течением и большей, чем на перекатах, глубиной
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> rett elve- eller kanalstrekning
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> плёс
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> utvidgning
# Processing code: https://www.geonames.org/ontology#R.TNLRD
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> vägtunnel
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> veitunnel
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> R.TNLRD
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#R
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> тоннель, через который проходит дорога
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> пътен тунел
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> road tunnel
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> автодорожный туннель
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#definition -> a tunnel through which a road passes
# Processing code: https://www.geonames.org/ontology#P.PPCLH
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#notation -> P.PPCLH
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#inScheme -> https://www.geonames.org/ontology#P
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#prefLabel -> historical capital of a political entity
#   Added SKOS triple: http://www.w3.org/2004/02/skos/core#historyNote -> Added in v3.1
# SKOS extraction complete. File saved as 'geonames_extracted_skos.rdf'.

# %%
def extract_flat_concepts(node):
    
    records_list = []

    for concept in root.findall(f'.//{node}'):
        if concept is not None:
            pref_label_value = concept.text
            if pref_label_value:
                record_dict = {
                    "prefLabel": pref_label_value,
                }
            
            records_list.append(record_dict)

    return records_list
for voc_label, voc_name in concept_singels.items():
    flat_concepts = extract_flat_concepts(voc_name)
    flat_unique_keys = remove_duplicates(flat_concepts)
    skos = generate_skos(flat_unique_keys, voc_label, 'flat')
    if voc_name == 'rightsURI':
        #print(json.dumps(flat_unique_keys, indent=2))

#for voc_label, voc_name in concept_singels.items():
#    flat_concepts = extract_nested_concepts(voc_name)

    #generate_skos(concepts, voc_label)
# Out:
#   Cell In[19], line 27
#
#     ^
# SyntaxError: incomplete input
