# %%
import os
import json
import pandas as pd
from lxml import etree
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, SKOS, DCTERMS, DC
import uuid


source_file = './out/monuments.xml'
tree = etree.parse(source_file)
root = tree.getroot()

concept_nodes = {"Religion Type": 'religionURI', "Religious Order Type": "religiousOrder", "Dedication Subject Type": "dedicationURI"}
concept_singels = {"Building Type": 'typeOfBuilding', "Building AAT Type": "additionalType", "Monument Status Type": "monumentStatus", "Rights Type": "rightsURI"}
ark_id = "1552"

# %%
def generate_skos(_list, _voc, _type):
    
    NS = Namespace("")
    g = Graph()
    g.bind("ns", NS)
    g.bind("skos", SKOS)
    g.bind("dcterms", DCTERMS)
    g.bind("dc", DC)

    voc_name = _voc
    voc_uri = f'https://n2t.net/ark:/{ark_id}/{voc_name.replace(" ", "")}/{str(uuid.uuid5(uuid.NAMESPACE_DNS, _voc))}'

    ns_voc_name = NS[voc_name]
    ns_voc_uri = NS[voc_uri]
    
    g.add((ns_voc_uri, RDF.type, SKOS['ConceptScheme']))
    g.add((ns_voc_uri, DCTERMS.title, Literal(voc_name,lang="nl")))
    g.add((ns_voc_uri, DCTERMS.title, Literal(voc_name,lang="en")))

    for row in _list:
        if _type == 'nested':
            uri = NS[str(row['about'])]
        elif _type == 'flat':
            flat_url = str(uuid.uuid5(uuid.NAMESPACE_DNS, row['prefLabel'].replace("resource=", "").replace("\"", "")))
            uri = NS[f'https://n2t.net/ark:/{ark_id}/{flat_url}']
        g.add((uri, SKOS.inScheme, ns_voc_uri))
        g.add((ns_voc_uri, SKOS.hasTopConcept, uri))
        
        g.add((uri, RDF.type, SKOS.Concept))
        g.add((uri, SKOS.prefLabel, Literal(row['prefLabel'].replace("resource=", "").replace("\"", ""), lang="nl")))
        g.add((uri, SKOS.inScheme, ns_voc_uri))
        if 'altLabel' in row:            
            for alt_label in row['altLabel']:
                g.add((uri, SKOS.altLabel, Literal(alt_label, lang="nl")))

    skos_data = g.serialize(format='pretty-xml').decode('utf-8')
    #print(skos_data)
    with open(f'./skos/{voc_name}.xml', "w") as f:
        f.write(skos_data)
    
    
    #skos_data = ''
    del g
    return skos_data

# %%
def remove_duplicates(dict_list):
    seen = set()  # Set to track unique prefLabel values
    unique_dicts = []  # List to store dictionaries without duplicates

    for d in dict_list:
        pref_label = d["prefLabel"]
        if pref_label not in seen:
            seen.add(pref_label)  # Add prefLabel to the seen set
            unique_dicts.append(d)  # Add the dictionary to the unique list

    return unique_dicts

# %%
def extract_nested_concepts(node):
    
    records_list = []

    for concepts in root.findall(f'.//{node}'):
        concept = concepts.find("Concept")
        if concept is not None:
            id_elem = concept.find("id")
            pref_label_elem = concept.find("prefLabel")
            alt_label_elems = concept.findall("altLabel")

            id_value = id_elem.text.replace("about=", "") if id_elem is not None and id_elem.text is not None else ""
            pref_label_value = pref_label_elem.text if pref_label_elem is not None and pref_label_elem.text is not None else ""

            alt_labels = [alt_label.text for alt_label in alt_label_elems if alt_label.text is not None]

            if pref_label_value:
                record_dict = {
                    "prefLabel": pref_label_value,
                    "about": id_value,
                    "altLabel": alt_labels
                }
                records_list.append(record_dict)

    return records_list

for voc_label, voc_name in concept_nodes.items():
    concepts = extract_nested_concepts(voc_name)
    unique_keys = remove_duplicates(concepts)
    skos = generate_skos(unique_keys, voc_label, 'nested')
    #print(skos)

# %%
def extract_flat_concepts(node):
    
    records_list = []

    for concept in root.findall(f'.//{node}'):
        if concept is not None:
            pref_label_value = concept.text
            if pref_label_value:
                record_dict = {
                    "prefLabel": pref_label_value,
                }
            
            records_list.append(record_dict)

    return records_list
for voc_label, voc_name in concept_singels.items():
    flat_concepts = extract_flat_concepts(voc_name)
    flat_unique_keys = remove_duplicates(flat_concepts)
    skos = generate_skos(flat_unique_keys, voc_label, 'flat')

#for voc_label, voc_name in concept_singels.items():
#    flat_concepts = extract_nested_concepts(voc_name)

    #generate_skos(concepts, voc_label)

# %%
def extract_rights_concepts(node):
    records_list = []

    for concept in root.findall(f'.//{node}'):
        if concept is not None:
            pref_label_value = concept.text
            if pref_label_value:
                record_dict = {
                    "rights_uri": pref_label_value.replace("resource=", "").replace("\"", ""),
                }
            
            records_list.append(record_dict)

    return records_list

flat_rights_concepts = extract_rights_concepts('rightsURI')
flat_unique_keys = remove_duplicates(flat_rights_concepts)
print(len(flat_unique_keys))
print(json.dumps(flat_rights_concepts, indent=2))
# Out:
# 172
# [
#   {
#     "prefLabel": "http://creativecommons.org/publicdomain/zero/1.0/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2274"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1759"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1764"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/licenses/by-sa/3.0/"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2195"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1752"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2181"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1850"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0/"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q6848"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/publicdomain/zero/1.0/"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q6860"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/publicdomain/zero/1.0/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1433"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/licenses/by-sa/3.0/"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2305"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1499"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2298"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2308"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1517"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1543"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2289"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1591"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1585"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1595"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/publicdomain/zero/1.0/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1731"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1604"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2295"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2311"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1668"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1890"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1894"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/deed.en"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2288"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1345"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/licenses/by-sa/3.0/"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1903"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1750"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0/"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q6840"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0/"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q6839"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/licenses/by-sa/3.0/"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1958"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2302"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1968"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1963"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1971"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1965"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1967"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1972"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1573"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1981"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1320"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1707"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1372"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/publicdomain/zero/1.0/deed.en"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/deed.en"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/publicdomain/zero/1.0/deed.en"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/publicdomain/zero/1.0/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1398"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1404"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1405"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1408"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1399"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/licenses/by-sa/3.0/"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1466"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/publicdomain/zero/1.0/deed.en"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/publicdomain/zero/1.0/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1416"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1417"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1491"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/publicdomain/zero/1.0/deed.en"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1439"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1421"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1497"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by/3.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1495"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1498"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/deed.en"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/deed.en"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1444"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1445"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1446"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2291"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1765"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1474"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1529"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/licenses/by-sa/3.0/"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1528"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/publicdomain/zero/1.0/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1627"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1962"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1613"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2256"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1805"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1806"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/publicdomain/zero/1.0/deed.en"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/publicdomain/zero/1.0/deed.en"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/publicdomain/zero/1.0/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1664"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1665"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2287"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1656"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/publicdomain/zero/1.0/deed.en"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/publicdomain/zero/1.0/deed.en"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/publicdomain/zero/1.0/deed.en"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/publicdomain/zero/1.0/deed.en"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/publicdomain/zero/1.0/deed.en"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/publicdomain/zero/1.0/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1666"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1661"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1663"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1654"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1660"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1662"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/2.5"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2297"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1708"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2285"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1969"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/publicdomain/zero/1.0/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1737"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2304"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by/3.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2303"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/publicdomain/zero/1.0/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1779"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2292"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/publicdomain/zero/1.0/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1777"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1785"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/publicdomain/zero/1.0/deed.en"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/publicdomain/zero/1.0/deed.en"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/publicdomain/zero/1.0/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1793"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1792"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1795"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/publicdomain/zero/1.0/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2310"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1761"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q6849"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1754"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1881"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1877"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1878"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1925"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1896"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1904"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1892"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1899"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1961"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/2.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1763"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2078"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2206"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2037"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2069"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2103"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/publicdomain/zero/1.0/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2221"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2006"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2027"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2143"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2167"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1994"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2187"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by/3.0"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1486"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2147"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/licenses/by-sa/3.0/"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1476"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2300"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2309"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1936"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0/"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q6944"
#   },
#   {
#     "prefLabel": "https://en.wikipedia.org/wiki/Public_domain"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q6945"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1480"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/publicdomain/zero/1.0/"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0/"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q6845"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q6842"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0/"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0/"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q6844"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q6843"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0/"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q6841"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2090"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0/"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/publicdomain/zero/1.0/"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q6846"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q6847"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q6838"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0/"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q6926"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0/"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q6946"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2153"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0/"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q6912"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by/4.0/"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q6914"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0/"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q6929"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0/"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q6932"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by/4.0/"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q6936"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1637"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1633"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by/3.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2151"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/4.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1612"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0/nl/deed.en"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1927"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/licenses/by-sa/3.0"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q1926"
#   },
#   {
#     "prefLabel": "http://creativecommons.org/licenses/by-sa/3.0/"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q2177"
#   },
#   {
#     "prefLabel": "https://creativecommons.org/publicdomain/zero/1.0/deed.nl"
#   },
#   {
#     "prefLabel": "http://gebouwen.brabantcloud.nl/entity/Q7015"
#   }
# ]
